# %% [markdown]
# <a href="https://colab.research.google.com/github/MaximKray21/CV_Projects/blob/main/Mask_Wearing_Detection/Mask_Wearing_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="cVa1yM9vH38i6uTOU8RU")
project = rf.workspace("joseph-nelson").project("mask-wearing")
dataset = project.version(18).download("yolov8")

# %%
# !pip install ultralytics
from ultralytics import YOLO

# %%
# !yolo detect train data={dataset.location}/data.yaml model=yolov8n.pt epochs=20 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 118MB/s]
# Ultralytics YOLOv8.1.3 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
